# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Debug: Load CSV String

# %%
data = """```plaintext
"Voucher Type","Customer Name","Customer Address","Customer State","Customer GSTIN","Supplier Name","Supplier Address","Supplier State","Supplier GSTIN","Document Number","Document Date","Narration"
"Sales","ACCO SPACE SOLUTIONS LLP","No 36/5 27TH MAIN RD ITI LAYOUT, BANGALORE, 560102","KARNATAKA","29ABNFA1370M1Z1","TATA TELESERVICES LTD","30/01 Silicon Terraces, Hosur Road, Bangalore, Karnataka - 560095","KARNATAKA","29AAACT2438A1ZP","3015635256","02/01/2024","Managed Enterprise Internet Service for December 2023"
"HSN Code","Product Name","Quantity","Quantity Unit","Rate","Currency","Discount","Taxable Amount","Tax Rate","Tax Amount","Total Amount"
"998421","Managed Enterprise Internet Service","1","Nos","137500.00","INR","0","137500.00","18.00","24750.00","162250.00"
```"""

# %%
import src.parse_pdf as parse_pdf
import src.tally_connector as tc

common_df, items_df = parse_pdf.process_csv_string(data)

# %%
import pymupdf

filename = "../invoices/9.pdf"
pages = pymupdf.get_text(filename)
text = "\n\n\n".join(pages)
print(text)
# Out:
# Invoice No.
# e-Way Bill No.
# LGF/24/01370
# 161847447105
# Tax Invoice
# LOOKING GOOD FURNITURE LLP
# NO. 99/2, Adur village, Bidarahalli Hobil
# Virgonagar, Bengaluru
# Bengaluru Urban
# Karnataka, 560049
# GSTIN/UIN: 29AAJFL9399L1Z5
# Dated
# 26/04/2024
# E-Way Bill Date.
# 2024-04-26 14:23:00
# IRN Date.
# 2024-04-26 14:22:00
# IRN No.
# cf48025b41bf16b1d94aceddf12fddb514e24c0dd5135d58105a81188709facb
# Buyer (Bill to)
# COUCHPOTATO
# NO 23 100 FT RING ROAD
# IIND STAGE BTM LAYOUT
# Bangalore
# GSTIN/UIN :29AOQPS5823M1ZY
# State Name :Karnataka, Code : 560076
# Phone :07019994660
# E-Mail :shettynaveen911@gmail.com
# Buyer’s Order No.
# Dispatch Doc No.
# 24/01370
# Vehcle No:MH04LY6371
# Buyer (Ship to)
# COUCHPOTATO
# NO 23 100 FT RING ROAD
# IIND STAGE BTM LAYOUT
# Bangalore
# GSTIN/UIN :29AOQPS5823M1ZY
# State Name :Karnataka, Code : 560076
# Phone :07019994660
# E-Mail :shettynaveen911@gmail.com
# Sl No.
# Description of Goods
# HSN/SAC
# Quantity
# UOM
# Rate
# SGST
# CGST
# IGST
# Amount
# 1
# Center Table A107
# 94034000
# 1.00
# PCS
# 9,144.07
# 822.97
# 822.97
# 10790.0
# 2
# Corner Table A107
# 94034000
# 1.00
# PCS
# 5,776.27
# 519.86
# 519.86
# 6816.0
# 3
# Center Table SC-S03
# 94034000
# 1.00
# PCS
# 12,513.56
# 1126.22
# 1126.22
# 14766.0
# 4
# Corner Table SC-S03
# 94034000
# 1.00
# PCS
# 6,738.14
# 606.43
# 606.43
# 7951.01
# 5
# Center Table CT-4
# 94034000
# 1.00
# PCS
# 12,513.56
# 1126.22
# 1126.22
# 14766.0
# 6
# Corner Table CT-4
# 94034000
# 1.00
# PCS
# 6,738.14
# 606.43
# 606.43
# 7951.01
# 7
# Center Table V05# (set of 2)
# 94034000
# 1.00
# PCS
# 6,545.76
# 589.12
# 589.12
# 7724.0
# 8
# Center Table A112
# 94034000
# 1.00
# PCS
# 18,288.98
# 1646.01
# 1646.01
# 21581.0
# 9
# Center Table E38
# 94034000
# 1.00
# PCS
# 14,438.14
# 1299.43
# 1299.43
# 17037.01
# 10
# Corner Table E38
# 94034000
# 1.00
# PCS
# 6,738.10
# 606.43
# 606.43
# 7950.96
# 11
# Center Table AS63-1 (Titanium)
# 94034000
# 1.00
# PCS
# 5,776.27
# 519.86
# 519.86
# 6816.0
# 12
# Corner Table AS63-1 (Titanium)
# 94034000
# 1.00
# PCS
# 3,850.48
# 346.54
# 346.54
# 4543.57
# 13
# Center Table CT2350
# 94034000
# 1.00
# PCS
# 17,327.12
# 1559.44
# 1559.44
# 20446.0
# 14
# Center table AH-777
# 94034000
# 1.00
# PCS
# 4,813.33
# 433.2
# 433.2
# 5679.73
# 15
# Corner Table AH-777
# 94034000
# 1.00
# PCS
# 2,405.93
# 216.53
# 216.53
# 2839.0
# 16
# Center Table AS63 (Gold)
# 94034000
# 1.00
# PCS
# 5,776.27
# 519.86
# 519.86
# 6816.0
# 17
# Corner Table AS63 (Gold)
# 94034000
# 1.00
# PCS
# 3,850.00
# 346.5
# 346.5
# 4543.0
# 18
# Center Table A82 (S909)
# 94034000
# 1.00
# PCS
# 11,550.85
# 1039.58
# 1039.58
# 13630.0
# 19
# Corner Table A82 (S909)
# 94034000
# 1.00
# PCS
# 6,738.14
# 606.43
# 606.43
# 7951.01
# 20
# Console X34
# 94034000
# 1.00
# PCS
# 18,288.98
# 1646.01
# 1646.01
# 21581.0
# 21
# Center Table AH-2462
# 94034000
# 1.00
# PCS
# 9,626.27
# 866.36
# 866.36
# 11359.0
# 22
# Corner Table AH-2462
# 94034000
# 1.00
# PCS
# 4,812.71
# 433.14
# 433.14
# 5679.0
# 23
# Centre Table AS46 (1+2) Gold
# 94034000
# 1.00
# PCS
# 16,845.76
# 1516.12
# 1516.12
# 19878.0
# 24
# Console Table S934
# 94034000
# 1.00
# PCS
# 17,807.63
# 1602.69
# 1602.69
# 21013.0
# 25
# Center Table S965
# 94034000
# 1.00
# PCS
# 16,364.41
# 1472.8
# 1472.8
# 19310.0
# 26
# Center Table C06
# 94034000
# 1.00
# PCS
# 7,700.85
# 693.08
# 693.08
# 9087.0
# 27
# Corner Table C06
# 94034000
# 1.00
# PCS
# 6,256.78
# 563.11
# 563.11
# 7383.0
# 28
# Console Table S919
# 94034000
# 1.00
# PCS
# 17,807.63
# 1602.69
# 1602.69
# 21013.0
# 29
# Center Table E213
# 94034000
# 1.00
# PCS
# 11,550.85
# 1039.58
# 1039.58
# 13630.0
# 30
# Corner Table E213
# 94034000
# 1.00
# PCS
# 7,220.34
# 649.83
# 649.83
# 8520.0
# 31
# Sofa Set BC10111 (2Str)
# 94034000
# 1.00
# PCS
# 34,654.24
# 3118.88
# 3118.88
# 40892.0
# Contact Details :
# LG Warehouse
# Mobile :
# E-Mail :lg_warehouse@ds.com
#
#
#
# Amount Chargeable (in words)
# E. & O.E
# 32
# Sofa Set BC10111 (3Str)
# 94034000
# 1.00
# PCS
# 45,242.37
# 4071.81
# 4071.81
# 53386.0
# 33
# Sofa Set 6571 ( 2 Str )
# 94034000
# 1.00
# PCS
# 33,690.68
# 3032.16
# 3032.16
# 39755.0
# 34
# Sofa Set 6571 ( 3 Str )
# 94034000
# 1.00
# PCS
# 43,316.95
# 3898.53
# 3898.53
# 51114.0
# 35
# Sofa Set BC10155 (2Str)
# 94016100
# 1.00
# PCS
# 34,654.24
# 3118.88
# 3118.88
# 40892.0
# 36
# Sofa Set BC10155 (3Str)
# 94034000
# 1.00
# PCS
# 45,241.90
# 4071.77
# 4071.77
# 53385.44
# 37
# Sofa Set BC10153 (2Str)
# 94034000
# 1.00
# PCS
# 31,766.10
# 2858.95
# 2858.95
# 37484.0
# 38
# Sofa Set BC10153 (3Str)
# 94034000
# 1.00
# PCS
# 42,354.24
# 3811.88
# 3811.88
# 49978.0
# 39
# Sofa Set 6357 2str ( Blue)
# 94034000
# 1.00
# PCS
# 34,654.24
# 3118.88
# 3118.88
# 40892.0
# 40
# Sofa Set 6357 3str ( Blue)
# 94034000
# 1.00
# PCS
# 49,093.22
# 4418.39
# 4418.39
# 57930.0
# 41
# Sofa Set CH6331 ( 1 Str ) Blue
# 94034000
# 1.00
# PCS
# 27,915.25
# 2512.37
# 2512.37
# 32939.99
# 42
# Sofa Set C-20701 (2 Str)
# 94034000
# 1.00
# PCS
# 38,504.24
# 3465.38
# 3465.38
# 45435.0
# 43
# Sofa Set C-20701 (3 Str)
# 94034000
# 1.00
# PCS
# 48,129.66
# 4331.67
# 4331.67
# 56793.0
# 44
# Dining Table 2028 (6 Str)
# 94034000
# 1.00
# PCS
# 39,466.95
# 3552.03
# 3552.03
# 46571.0
# 45
# Dining Chair CL-1058 Green
# 94034000
# 4.00
# PCS
# 8,181.99
# 2945.52
# 2945.52
# 38618.99
# 46
# Dining Bench CL-1080 Green
# 94034000
# 1.00
# PCS
# 15,883.05
# 1429.47
# 1429.47
# 18742.0
# 47
# Sofa Set EM0787(2str)
# 94034000
# 1.00
# PCS
# 47,166.95
# 4245.03
# 4245.03
# 55657.0
# 48
# Sofa Set EM0787 (3 Str)
# 94034000
# 1.00
# PCS
# 51,979.66
# 4678.17
# 4678.17
# 61336.0
# 49
# Garden Set TY-20231206 (1+2)
# 94034000
# 1.00
# PCS
# 16,845.76
# 1516.12
# 1516.12
# 19878.0
# 50
# Garden Set S-25 (1+2)
# 94034000
# 1.00
# PCS
# 12,994.92
# 1169.54
# 1169.54
# 15334.01
# 51
# Garden Set 109+52 (1+2)
# 94034000
# 1.00
# PCS
# 14,438.98
# 1299.51
# 1299.51
# 17038.0
# 52
# Garden Set 8065 (1+2)
# 94034000
# 1.00
# PCS
# 13,476.27
# 1212.86
# 1212.86
# 15902.0
# 53
# Dining Chair 2802
# 94034000
# 6.00
# PCS
# 6,930.65
# 3742.55
# 3742.55
# 49069.0
# 54
# Dining Table 2303 + BY (8 Str) 2.1
# 94034000
# 1.00
# PCS
# 52,943.22
# 4764.89
# 4764.89
# 62473.0
# 55
# Dining Chair WDC320B
# 94034000
# 8.00
# PCS
# 6,738.21
# 4851.51
# 4851.51
# 63608.7
# 56
# Dining Table 687 Base + BK Top
# 94034000
# 1.00
# PCS
# 25,027.97
# 2252.52
# 2252.52
# 29533.0
# 57
# Dining Chair C01
# 94034000
# 6.00
# PCS
# 6,930.65
# 3742.55
# 3742.55
# 49069.0
# 58
# Dining Table U91+18 (6 Str)
# 94034000
# 1.00
# PCS
# 25,989.83
# 2339.08
# 2339.08
# 30668.0
# 59
# Dining Chair 231
# 94034000
# 6.00
# PCS
# 6,738.14
# 3638.6
# 3638.6
# 47706.03
# 60
# Dining Table T07+BBH Onyx (6str) 1.8
# 94034000
# 1.00
# PCS
# 38,504.24
# 3465.38
# 3465.38
# 45435.0
# 61
# Dining Chair CL 1058 Grey
# 94034000
# 4.00
# PCS
# 8,181.90
# 2945.48
# 2945.48
# 38618.57
# 62
# Dining Bench CL 1080 Gey
# 94034000
# 1.00
# PCS
# 15,883.05
# 1429.47
# 1429.47
# 18742.0
# 63
# Garden Set X-12 (1+4)
# 94034000
# 1.00
# PCS
# 15,400.85
# 1386.08
# 1386.08
# 18173.0
# Rounding :
# 0.01
# Total :
# ₹ 1,692,099.00
# Sl No.
# Description of Goods
# HSN/SAC
# Quantity
# UOM
# Rate
# SGST
# CGST
# IGST
# Amount
# INR one million, six hundred and ninety-two thousand and ninety-nine and zero paise Only
# HSN/SAC
# Taxable Value
# Central Tax
# State Tax
# IGST
# Total
# Rate
# Amount
# Rate
# Amount
# Rate
# Amount
# 94034000
# ₹ 9,144.07
# 9.0%
# 822.97
# 9.0%
# 822.97
# 1645.93
# 94034000
# ₹ 5,776.27
# 9.0%
# 519.86
# 9.0%
# 519.86
# 1039.73
# 94034000
# ₹ 12,513.56
# 9.0%
# 1126.22
# 9.0%
# 1126.22
# 2252.44
# 94034000
# ₹ 6,738.14
# 9.0%
# 606.43
# 9.0%
# 606.43
# 1212.87
# 94034000
# ₹ 12,513.56
# 9.0%
# 1126.22
# 9.0%
# 1126.22
# 2252.44
# 94034000
# ₹ 6,738.14
# 9.0%
# 606.43
# 9.0%
# 606.43
# 1212.87
# 94034000
# ₹ 6,545.76
# 9.0%
# 589.12
# 9.0%
# 589.12
# 1178.24
# 94034000
# ₹ 18,288.98
# 9.0%
# 1646.01
# 9.0%
# 1646.01
# 3292.02
# 94034000
# ₹ 14,438.14
# 9.0%
# 1299.43
# 9.0%
# 1299.43
# 2598.87
# 94034000
# E-Mail :lg_warehouse@ds.com
#
#
#
# Declaration
# 1. We declare that the details shown in this Invoice are true and correct.
# 2. Goods once sold cannot be taken back or Exchanged.
# 3. Our Responsibility seizes once product reaches customer’s place in good
# condition.
# 4. No Guarantee for Glass items. Received Goods in good Condition
# Customer’s Signature :
# for LOOKING GOOD FURNITURE LLP
# Authorised Signatory
# Tax Amount (in words) :INR two hundred and fifty-eight thousand, one hundred and sixteen and seventy-six paise Only
# Contact Details :
# LG Warehouse
# Mobile :
# E-Mail :lg_warehouse@ds.com

# %% [markdown]
# ## Load PDF

# %%
import src.parse_pdf as parse_pdf
import src.tally_connector as tc

company_name = tc.get_tally_company()
filename = "./invoices//10.pdf"
common_df, items_df = parse_pdf.parse_pdf(company_name, filename)

display(common_df)
display(items_df)
# Out:
# ================================== Ai Message ==================================
#
# Based on the provided invoice text, we need to determine the appropriate voucher type and prepare the data for Tally import. The invoice indicates that CouchPotato is the buyer, as the invoice is issued by Tata Teleservices Ltd to ACCO SPACE SOLUTIONS LLP, which is associated with CouchPotato. Therefore, the voucher type is **Purchase**.
#
# Here is the CSV-formatted data for Tally import:
#
# ```
# "Voucher Type","Customer Name","Customer Address","Customer State","Customer GSTIN","Supplier Name","Supplier Address","Supplier State","Supplier GSTIN","Document Number","Document Date","Narration"
# "Purchase","ACCO SPACE SOLUTIONS LLP","No 36/5 27TH MAIN RD ITI LAYOUT, BANGALORE, 560102","KARNATAKA","29ABNFA1370M1Z1","TATA TELESERVICES LTD","30/01 Silicon Terraces, Hosur Road, Bangalore, Karnataka - 560095","KARNATAKA","29AAACT2438A1ZP","3015635256","02/01/2024","Purchase of Managed Enterprise Internet Service"
# "HSN Code","Product Name","Quantity","Quantity Unit","Rate","Currency","Discount","Taxable Amount","Tax Rate","Tax Amount","Total Amount"
# "998421","Managed Enterprise Internet Service","1","Nos","137500.00","INR","0","137500.00","18","24750.00","162250.00"
# ```
#
# This output includes the necessary details for a purchase entry, with the invoice line item reflecting the service purchased, its HSN code, and the applicable taxes.
# ChatGPT Response Metadata: {'token_usage': {'completion_tokens': 341, 'prompt_tokens': 3526, 'total_tokens': 3867, 'completion_tokens_details': {'audio_tokens': 0, 'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3328}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_159d8341cc', 'finish_reason': 'stop', 'logprobs': None}
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 6
#       4 company_name = tc.get_tally_company()
#       5 filename = "./invoices//10.pdf"
# ----> 6 common_df, items_df = parse_pdf.parse_pdf(company_name, filename)
#       8 display(common_df)
#       9 display(items_df)
#
# File c:\Users\laxma\Repository\data-entry-ai\src\parse_pdf.py:88, in parse_pdf(company_name, pdf_file)
#      86     with pymupdf.open(stream=pdf_file.read()) as doc:
#      87         pages = [page.get_text() for page in doc]
# ---> 88 text = "\n\n\n".join(pages)
#      90 llm = ChatOpenAI(model="gpt-4o", temperature=0.3)
#      91 prompt = create_prompt(company_name, text)
#
# File c:\Users\laxma\Repository\data-entry-ai\src\parse_pdf.py:68, in process_csv_string(csv_string)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\laxma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\Local\pypoetry\Cache\virtualenvs\data-entry-ai-6LafD0Kq-py3.12\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\laxma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\Local\pypoetry\Cache\virtualenvs\data-entry-ai-6LafD0Kq-py3.12\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\laxma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\Local\pypoetry\Cache\virtualenvs\data-entry-ai-6LafD0Kq-py3.12\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\laxma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\Local\pypoetry\Cache\virtualenvs\data-entry-ai-6LafD0Kq-py3.12\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 12

# %%
import src.tally_connector as tc

tc.match_masters(common_df, items_df)
display(common_df)
display(items_df)
# Out:
#   Voucher Type Customer Name  \
# 0        Sales   COUCHPOTATO
#
#                                     Customer Address Customer State  \
# 0  NO 23 100 FT RING ROAD, IIND STAGE BTM LAYOUT,...      Karnataka
#
#     Customer GSTIN               Supplier Name  \
# 0  29AOQPS5823M1ZY  LOOKING GOOD FURNITURE LLP
#
#                                     Supplier Address Supplier State  \
# 0  NO. 99/2, Adur village, Bidarahalli Hobil, Vir...      Karnataka
#
#     Supplier GSTIN Document Number Document Date  \
# 0  29AAJFL9399L1Z5    LGF/24/01370    26/04/2024
#
#                                            Narration Party Account  \
# 0  Invoice for furniture purchase, E-Way Bill No:...   COUCHPOTATO
#
#   [D] Party Account
# 0       COUCHPOTATO
#     HSN code                          Product Name  Quantity Quantity Unit  \
# 0   94034000                     Center Table A107         1           PCS
# 1   94034000                     Corner Table A107         1           PCS
# 2   94034000                   Center Table SC-S03         1           PCS
# 3   94034000                   Corner Table SC-S03         1           PCS
# 4   94034000                     Center Table CT-4         1           PCS
# ..       ...                                   ...       ...           ...
# 58  94034000                      Dining Chair 231         6           PCS
# 59  94034000  Dining Table T07+BBH Onyx (6str) 1.8         1           PCS
# 60  94034000             Dining Chair CL 1058 Grey         4           PCS
# 61  94034000              Dining Bench CL 1080 Gey         1           PCS
# 62  94034000                 Garden Set X-12 (1+4)         1           PCS
#
#         Rate Currency  Discount  Taxable Amount  Tax Rate  Tax Amount  \
# 0    9144.07      INR         0         9144.07        18     1645.93
# 1    5776.27      INR         0         5776.27        18     1039.73
# 2   12513.56      INR         0        12513.56        18     2252.44
# 3    6738.14      INR         0         6738.14        18     1212.87
# 4   12513.56      INR         0        12513.56        18     2252.44
# ..       ...      ...       ...             ...       ...         ...
# 58   6738.14      INR         0        40428.84        18     7277.19
# 59  38504.24      INR         0        38504.24        18     6930.76
# 60   8181.90      INR         0        32727.60        18     5890.97
# 61  15883.05      INR         0        15883.05        18     2858.95
# 62  15400.85      INR         0        15400.85        18     2772.15
#
#     Total Amount [D] Stock Item [D] Units
# 0       10790.00           None       PCS
# 1        6816.00           None       PCS
# 2       14766.00           None       PCS
# 3        7951.01           None       PCS
# 4       14766.00           None       PCS
# ..           ...            ...       ...
# 58      47706.03           None       PCS
# 59      45435.00           None       PCS
# 60      38618.57           None       PCS
# 61      18742.00           None       PCS
# 62      18173.00           None       PCS
#
# [63 rows x 13 columns]

# %%
from src.verify_df import verify_amounts

errors = verify_amounts(items_df)
errors
# Out:
# []

# %%
total_tax = items_df["Tax Amount"].sum()
total_tax
# Out:
# 258116.80000000002

# %%
import src.tally.create_masters as create_masters

create_masters.create_masters(common_df, items_df)
# Out:
# Created Stock Item: Center Table A107
# Created Stock Item: Corner Table A107
# Created Stock Item: Center Table SC-S03
# Created Stock Item: Corner Table SC-S03
# Created Stock Item: Center Table CT-4
# Created Stock Item: Corner Table CT-4
# Created Stock Item: Center Table V05# (set of 2)
# Created Stock Item: Center Table A112
# Created Stock Item: Center Table E38
# Created Stock Item: Corner Table E38
# Created Stock Item: Center Table AS63-1 (Titanium)
# Created Stock Item: Corner Table AS63-1 (Titanium)
# Created Stock Item: Center Table CT2350
# Created Stock Item: Center table AH-777
# Created Stock Item: Corner Table AH-777
# Created Stock Item: Center Table AS63 (Gold)
# Created Stock Item: Corner Table AS63 (Gold)
# Created Stock Item: Center Table A82 (S909)
# Created Stock Item: Corner Table A82 (S909)
# Created Stock Item: Console X34
# Created Stock Item: Center Table AH-2462
# Created Stock Item: Corner Table AH-2462
# Created Stock Item: Centre Table AS46 (1+2) Gold
# Created Stock Item: Console Table S934
# Created Stock Item: Center Table S965
# Created Stock Item: Center Table C06
# Created Stock Item: Corner Table C06
# Created Stock Item: Console Table S919
# Created Stock Item: Center Table E213
# Created Stock Item: Corner Table E213
# Created Stock Item: Sofa Set BC10111 (2Str)
# Created Stock Item: Sofa Set BC10111 (3Str)
# Created Stock Item: Sofa Set 6571 ( 2 Str )
# Created Stock Item: Sofa Set 6571 ( 3 Str )
# Created Stock Item: Sofa Set BC10155 (2Str)
# Created Stock Item: Sofa Set BC10155 (3Str)
# Created Stock Item: Sofa Set BC10153 (2Str)
# Created Stock Item: Sofa Set BC10153 (3Str)
# Created Stock Item: Sofa Set 6357 2str ( Blue)
# Created Stock Item: Sofa Set 6357 3str ( Blue)
# Created Stock Item: Sofa Set CH6331 ( 1 Str ) Blue
# Created Stock Item: Sofa Set C-20701 (2 Str)
# Created Stock Item: Sofa Set C-20701 (3 Str)
# Created Stock Item: Dining Table 2028 (6 Str)
# Created Stock Item: Dining Chair CL-1058 Green
# Created Stock Item: Dining Bench CL-1080 Green
# Created Stock Item: Sofa Set EM0787(2str)
# Created Stock Item: Sofa Set EM0787 (3 Str)
# Created Stock Item: Garden Set TY-20231206 (1+2)
# Created Stock Item: Garden Set S-25 (1+2)
# Created Stock Item: Garden Set 109+52 (1+2)
# Created Stock Item: Garden Set 8065 (1+2)
# Created Stock Item: Dining Chair 2802
# Created Stock Item: Dining Table 2303 + BY (8 Str) 2.1
# Created Stock Item: Dining Chair WDC320B
# Created Stock Item: Dining Table 687 Base + BK Top
# Created Stock Item: Dining Chair C01
# Created Stock Item: Dining Table U91+18 (6 Str)
# Created Stock Item: Dining Chair 231
# Created Stock Item: Dining Table T07+BBH Onyx (6str) 1.8
# Created Stock Item: Dining Chair CL 1058 Grey
# Created Stock Item: Dining Bench CL 1080 Gey
# Created Stock Item: Garden Set X-12 (1+4)

# %%
import src.tally.create_vouchers as create_vouchers

create_vouchers.create_vouchers(common_df, items_df)
