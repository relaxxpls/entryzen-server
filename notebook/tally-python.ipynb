# %%
import sys
from pythonnet import load

load("coreclr")
sys.path.append("./TallyConnector")

import clr

clr.AddReference("TallyConnector")

# %%
from TallyConnector.Services import TallyService

tally = TallyService()
isRunning = tally.CheckAsync().Result
isRunning
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundException                     Traceback (most recent call last)
# FileNotFoundException: Could not load file or assembly 'Microsoft.Extensions.Logging.Abstractions, Version=7.0.0.0, Culture=neutral, PublicKeyToken=adb9793829ddae60'. The system cannot find the file specified.
# File name: 'Microsoft.Extensions.Logging.Abstractions, Version=7.0.0.0, Culture=neutral, PublicKeyToken=adb9793829ddae60'
#    at System.Signature.GetSignature(Void* pCorSig, Int32 cCorSig, RuntimeFieldHandleInternal fieldHandle, IRuntimeMethodInfo methodHandle, RuntimeType declaringType)
#    at System.Reflection.RuntimeMethodInfo.<get_Signature>g__LazyCreateSignature|25_0()
#    at System.Reflection.RuntimeMethodInfo.ToString()
#    at Python.Runtime.MaybeMethodBase`1..ctor(T mi) in /home/benedikt/dev/pythonnet/dist/.tmpXppz4v/pythonnet-3.0.4/src/runtime/StateSerialization/MaybeMethodBase.cs:line 66
# ...

# %%
from datetime import datetime

from System import DateTime
from System.Collections.Generic import List
from TallyConnector.Services import *
from TallyConnector.Core.Models import *
from TallyConnector.Core.Models.Masters import *
from TallyConnector.Core.Models.Masters.Inventory import *
from TallyConnector.Core.Converters.XMLConverterHelpers import TallyDate

# Create a Ledger object
ledger = Ledger()
ledger.OldName = "TallAi - Purchase Account"
ledger.Name = "TallAi - Purchase Account"
ledger.Group = "Sundry Creditors - Purc
hases"

now = datetime.now()
now = DateTime(now.year, now.month, now.day, now.hour, now.minute, now.second)
now = TallyDate(now)

# Create a LedgerGSTRegistrationDetails object
gst_registration_details = LedgerGSTRegistrationDetails()
gst_registration_details.GSTIN = "27AACTT0001H1Z5"
gst_registration_details.State = "Maharashtra"
gst_registration_details.GSTRegistrationType = GSTRegistrationType.Regular
gst_registration_details.ApplicableFrom = now
ledger.LedgerGSTRegistrationDetails = List[LedgerGSTRegistrationDetails]()
ledger.LedgerGSTRegistrationDetails.Add(gst_registration_details)

# Create a LedgerMailingDetails object
mailing_details = LedgerMailingDetails()
mailing_details.Address = "Mumbai"
mailing_details.MailingName = "TallAi - Purchase Account"
mailing_details.State = "Maharashtra"
mailing_details.Country = "India"
mailing_details.PinCode = "400001"
mailing_details.ApplicableFrom = now
ledger.LedgerMailingDetails = List[LedgerMailingDetails]()
ledger.LedgerMailingDetails.Add(mailing_details)

# Call the PostLedgerAsync method
response = tally.PostLedgerAsync(ledger).Result
print(response)
# Out:
# TallyConnector.Core.Models.TallyResult

# %%
import pymupdf

pages = pymupdf.get_text("./invoices/2.pdf")
invoice_text = " ".join(pages)
print(invoice_text)
# Out:
#
# Tax Invoice/Bill of Supply/Cash Memo
# (Original for Recipient)
# *ASSPL-Amazon Seller Services Pvt. Ltd., ARIPL-Amazon Retail India Pvt. Ltd. (only where Amazon Retail India Pvt. Ltd. fulfillment center is co-located)
# Customers desirous of availing input GST credit are requested to create a Business account and purchase on Amazon.in/business from Business eligible offers
# Please note that this invoice is not a demand for payment
# Page  of
# 1
# 1
# For Appario Retail Private Ltd:
# Authorized Signatory
# Order Number: 406-8039558-0772324
#  BOM3-802591
# Invoice Number :
# Order Date: 06.01.2019
#  MH-BOM3-1034-1819
# Invoice Details :
#  06.01.2019
# Invoice Date :
# Sl.
# No Description
# Unit
# Price
# Discount Qty Net
# Amount
# Tax
# Rate
# Tax
# Type
# Tax
# Amount
# Total
# Amount
# 1 Sony Extra Bass SRS-XB10 Portable Splash-proof
# Wireless Speakers with Bluetooth and NFC (Blue) |
# B06Y5L25M4 ( B06Y5L25M4 )
# HSN:8518
# ₹2,788.14 ₹0.00
# ...

# %%
from src.parse_pdf import process_csv_string

msg = """```csv
"Voucher Type","Customer Name","Customer Address","Customer GSTIN","Supplier Name","Supplier Address","Supplier GSTIN","Document Number","Document Date"
"Sales","COUCHPOTATO","NO 23 100 FT RING ROAD, IIND STAGE BTM LAYOUT, Bangalore","29AOQPS5823M1ZY","LOOKING GOOD FURNITURE LLP","NO. 99/2, Adur village, Bidarahalli Hobil, Virgonagar, Bengaluru, Bengaluru Urban, Karnataka, 560049","29AAJFL9399L1Z5","LGF/24/01370","26/04/2024"
"HSN code","Product Name","Quantity","Quantity Unit","Rate","Discount","Taxable Amount","Tax Rate","Tax Amount","Total Amount"
"94034000","Center Table A107","1.00","PCS","9144.07","0","9144.07","18.0","1645.93","10790.00"
"94034000","Corner Table A107","1.00","PCS","5776.27","0","5776.27","18.0","1039.73","6816.00"
"94034000","Center Table SC-S03","1.00","PCS","12513.56","0","12513.56","18.0","2252.44","14766.00"
"94034000","Corner Table SC-S03","1.00","PCS","6738.14","0","6738.14","18.0","1212.87","7951.01"
"94034000","Center Table CT-4","1.00","PCS","12513.56","0","12513.56","18.0","2252.44","14766.00"
"94034000","Corner Table CT-4","1.00","PCS","6738.14","0","6738.14","18.0","1212.87","7951.01"
"94034000","Center Table V05# (set of 2)","1.00","PCS","6545.76","0","6545.76","18.0","1178.24","7724.00"
"94034000","Center Table A112","1.00","PCS","18288.98","0","18288.98","18.0","3292.02","21581.00"
"94034000","Center Table E38","1.00","PCS","14438.14","0","14438.14","18.0","2598.87","17037.01"
"94034000","Corner Table E38","1.00","PCS","6738.10","0","6738.10","18.0","1212.86","7950.96"
"94034000","Center Table AS63-1 (Titanium)","1.00","PCS","5776.27","0","5776.27","18.0","1039.73","6816.00"
"94034000","Corner Table AS63-1 (Titanium)","1.00","PCS","3850.48","0","3850.48","18.0","693.09","4543.57"
"94034000","Center Table CT2350","1.00","PCS","17327.12","0","17327.12","18.0","3118.88","20446.00"
"94034000","Center table AH-777","1.00","PCS","4813.33","0","4813.33","18.0","866.40","5679.73"
"94034000","Corner Table AH-777","1.00","PCS","2405.93","0","2405.93","18.0","433.07","2839.00"
"94034000","Center Table AS63 (Gold)","1.00","PCS","5776.27","0","5776.27","18.0","1039.73","6816.00"
"94034000","Corner Table AS63 (Gold)","1.00","PCS","3850.00","0","3850.00","18.0","693.00","4543.00"
"94034000","Center Table A82 (S909)","1.00","PCS","11550.85","0","11550.85","18.0","2079.15","13630.00"
"94034000","Corner Table A82 (S909)","1.00","PCS","6738.14","0","6738.14","18.0","1212.87","7951.01"
"94034000","Console X34","1.00","PCS","18288.98","0","18288.98","18.0","3292.02","21581.00"
"94034000","Center Table AH-2462","1.00","PCS","9626.27","0","9626.27","18.0","1732.73","11359.00"
"94034000","Corner Table AH-2462","1.00","PCS","4812.71","0","4812.71","18.0","866.29","5679.00"
"94034000","Centre Table AS46 (1+2) Gold","1.00","PCS","16845.76","0","16845.76","18.0","3032.24","19878.00"
"94034000","Console Table S934","1.00","PCS","17807.63","0","17807.63","18.0","3205.37","21013.00"
"94034000","Center Table S965","1.00","PCS","16364.41","0","16364.41","18.0","2945.59","19310.00"
"94034000","Dining Chair C01","6.00","PCS","6930.65","0","41583.90","18.0","7485.10","49069.00"
"94034000","Dining Table U91+18 (6 Str)","1.00","PCS","25989.83","0","25989.83","18.0","4678.17","30668.00"
"94034000","Dining Chair 231","6.00","PCS","6738.14","0","40428.84","18.0","7277.19","47706.03"
"94034000","Dining Table T07+BBH Onyx (6str) 1.8","1.00","PCS","38504.24","0","38504.24","18.0","6930.76","45435.00"
"94034000","Dining Chair CL 1058 Grey","4.00","PCS","8181.90","0","32727.60","18.0","5890.97","38618.57"
"94034000","Dining Bench CL 1080 Gey","1.00","PCS","15883.05","0","15883.05","18.0","2858.95","18742.00"
"94034000","Garden Set X-12 (1+4)","1.00","PCS","15400.85","0","15400.85","18.0","2772.15","18173.00"
```"""

common_df, items_df = process_csv_string(msg)
display(common_df.head())
display(items_df.head())
# Out:
#   Voucher Type Customer Name  ... Document Number Document Date
# 0        Sales   COUCHPOTATO  ...    LGF/24/01370    26/04/2024
#
# [1 rows x 9 columns]
#    HSN code         Product Name  Quantity  ... Tax Rate  Tax Amount  Total Amount
# 0  94034000    Center Table A107       1.0  ...     18.0     1645.93      10790.00
# 1  94034000    Corner Table A107       1.0  ...     18.0     1039.73       6816.00
# 2  94034000  Center Table SC-S03       1.0  ...     18.0     2252.44      14766.00
# 3  94034000  Corner Table SC-S03       1.0  ...     18.0     1212.87       7951.01
# 4  94034000    Center Table CT-4       1.0  ...     18.0     2252.44      14766.00
#
# [5 rows x 10 columns]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
display(common_df.head())
display(items_df.head())
# Out:
#   Voucher Type  ...                                  [D] Party Account
# 0        Sales  ...  LOOKING GOOD FURNITURE LLP -HYDERABAD\t\t\t\t\...
#
# [1 rows x 10 columns]
#    HSN code         Product Name  ...           [D] Stock Item [D] Units
# 0  94034000    Center Table A107  ...  A4000081 - CENTER TABLE       PCS
# 1  94034000    Corner Table A107  ...                     None       PCS
# 2  94034000  Center Table SC-S03  ...       211A3 CENTER TABLE       PCS
# 3  94034000  Corner Table SC-S03  ...                     None       PCS
# 4  94034000    Center Table CT-4  ...    CT-17125-CENTER TABLE       PCS
#
# [5 rows x 12 columns]

# %%
import src.tally_connector as tc

common_df2, items_df2 = tc.match_masters(common_df, items_df)

display(common_df2.head())
display(items_df2.head())
# Out:
# {'Center Table A107': 'A4000081 - CENTER TABLE', 'Corner Table A107': None, 'Center Table SC-S03': '211A3 CENTER TABLE', 'Corner Table SC-S03': None, 'Center Table CT-4': 'CT-17125-CENTER TABLE', 'Corner Table CT-4': None, 'Center Table V05# (set of 2)': None, 'Center Table A112': 'A4000081 - CENTER TABLE', 'Center Table E38': None, 'Corner Table E38': None, 'Center Table AS63-1 (Titanium)': 'T697-20 CENTER TABLE', 'Corner Table AS63-1 (Titanium)': None, 'Center Table CT2350': 'CT-17125-CENTER TABLE', 'Center table AH-777': None, 'Corner Table AH-777': None, 'Center Table AS63 (Gold)': None, 'Corner Table AS63 (Gold)': None, 'Center Table A82 (S909)': 'T892-9 CENTER TABLE', 'Corner Table A82 (S909)': None, 'Console X34': None, 'Center Table AH-2462': '211A3 CENTER TABLE', 'Corner Table AH-2462': None, 'Centre Table AS46 (1+2) Gold': None, 'Console Table S934': None, 'Center Table S965': 'T099-1 CENTER TABLE', 'Center Table C06': 'CT-17125-CENTER TABLE', 'Corner Table C06': None, 'Con
# ...
